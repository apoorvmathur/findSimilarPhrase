# %% [markdown]
# # Comparing word2vec embeddings for a user input phrase against a list of preloaded phrases

# %% [markdown]
# ## Loading dependancies

# %%
import os

import pandas as pd
import numpy as np

import gensim
from gensim.models import KeyedVectors

# %% [markdown]
# ## Setting paths for models and files

# %%
WORD2VEC_MODEL_PATH = "../models/GoogleNews-vectors-negative300.bin.gz"
PHRASES_FILE_PATH = "../data/phrases.csv"
VECTORS_FILE_PATH = "../data/vectors.csv"

# %%
# Check if VECTORS_FILE exists

if os.path.exists(VECTORS_FILE_PATH):
    print(f"Vectors file exists, loading from {VECTORS_FILE_PATH}")
    wv = KeyedVectors.load_word2vec_format(VECTORS_FILE_PATH)
elif os.path.exists(WORD2VEC_MODEL_PATH):
    print(f"Vectors file does not exist, loading from {WORD2VEC_MODEL_PATH}")
    wv = KeyedVectors.load_word2vec_format(WORD2VEC_MODEL_PATH, binary=True, limit=1000000)
    print(f"Saving vectors to {VECTORS_FILE_PATH}")
    wv.save_word2vec_format(VECTORS_FILE_PATH)
else:
    print("Word2Vec model not found. Please place the model at models/GoogleNews-vectors-negative300.bin.gz")
# Out:
# Vectors file exists, loading from ../data/vectors.csv

# %% [markdown]
# ## Loading Phrases CSV

# %%
phrases = pd.read_csv(PHRASES_FILE_PATH)

# %%
phrases
# Out:
#                                               Phrases
# 0                  how company compares to its peers?
# 1   what is the detailed income statement breakdow...
# 2                   world premium penetration in 2020
# 3   How does the forecasted insurance premium pene...
# 4   what are the total losses for companies in cou...
# 5                Insurance premiums market in Country
# 6   How have the profit margins been for the airli...
# 7   What is the complete profile of the top oil rigs?
# 8                what is company general information?
# 9    How is the airline industry performing globally?
# 10  how does economic profit for in country compar...
# 11            most profitable insurance company India
# 12  Give me a detailed breakup of the income and e...
# 13              Show me all the oil rigs in the world
# 14  What were the premiums earned by the Indian in...
# 15  How much have premiums grown as compared to cl...
# 16  Which are the best performing insurance firms ...
# 17              What is the ROE of the Indian market?
# 18  What profits were clocked by Cholamandalam in ...
# 19  What is the premiums market share of the top 5...
# 20  How will the Brazilian insurance market perfor...
# 21  Which are the main distribution channels in In...
# 22  What are the risks in the motor insurance segm...
# 23  What is the demand potential of India for insu...
# 24  How do premiums break down by lines of busines...
# 25                 What is the share price of Qantas?
# 26               How many passengers are carried in ?
# 27    Which are the aircrafts manufactured by Boeing?
# 28        Kdo je nejv?tší konkurent ?eské Pojiš?ovny?
# 29                        Which are the top airports?
# 30            How many fatal air accidents till date?
# 31  What is the flow of air traffic in North America?
# 32                       What is the fleet of Airbus?
# 33                     Airlines profitability Brazil?
# 34                   Mergers among airline companies?
# 35            Which are the most profitable airports?
# 36  What has the capacity movement of airline comp...
# 37               Details of the Aban Abraham oil rig?
# 38         How big is the airlines industry in China?
# 39  How much money did Lloyd's of London make last...
# 40  What was the Calendar year COR versus the Acci...
# 41  Which Lloyd's syndicates owns the maximum numb...
# 42           List key performance indicators for AXA?
# 43           What are the most prominent legal cases?
# 44           How does oil industry perform in Brazil?
# 45  What is the main driver of growth in automobil...
# 46  Which country in Europe is going to grow the m...
# 47         What are the biggest acquisitions in 2020?
# 48      How impacted is the airline industry in 2020?
# 49  What are the most prominent bankruptcies in 2020?

# %% [markdown]
# ## Defining functions to convert phrases to embeddings
#
#
# Making an assumption here, normalising the vector in the traditional sense, by dividing it by the norm of the said vector. \
# This might be incorrect for word2vec embeddings, or not. I'm not sure.

# %%
def get_phrase_vector(phrase):
    combined_vectors = None
    normalized_vector = None

    # Splitting phrase into words
    for word in phrase.split(): 
        try:
            vector = wv.get_vector(word)
            if combined_vectors is None:
                combined_vectors = vector
            else:
                combined_vectors = combined_vectors + vector
        except KeyError as e:
            print(f"Word {word} not found in the embeddings. Skipping.")

    # Normalising the vector, not sure if this is correct for word2vec vectors
    if combined_vectors is not None:
        norm = np.linalg.norm(combined_vectors)
        normalized_vector = combined_vectors / norm
    
    return normalized_vector

# %% [markdown]
# ## Computing embeddings for all given phrases

# %%
phrases['Embedding'] = phrases['Phrases'].apply(get_phrase_vector)
# Out:
# Word to not found in the embeddings. Skipping.
# Word peers? not found in the embeddings. Skipping.
# Word of not found in the embeddings. Skipping.
# Word Axa? not found in the embeddings. Skipping.
# Word 2020 not found in the embeddings. Skipping.
# Word to not found in the embeddings. Skipping.
# Word peers? not found in the embeddings. Skipping.
# Word market? not found in the embeddings. Skipping.
# Word years, not found in the embeddings. Skipping.
# Word regions? not found in the embeddings. Skipping.
# Word of not found in the embeddings. Skipping.
# Word rigs? not found in the embeddings. Skipping.
# Word information? not found in the embeddings. Skipping.
# Word globally? not found in the embeddings. Skipping.
# Word to not found in the embeddings. Skipping.
# Word others? not found in the embeddings. Skipping.
# Word a not found in the embeddings. Skipping.
# Word of not found in the embeddings. Skipping.
# Word and not found in the embeddings. Skipping.
# Word South-East not found in the embeddings. Skipping.
# Word 2020? not found in the embeddings. Skipping.
# Word to not found in the embeddings. Skipping.
# Word India? not found in the embeddings. Skipping.
# Word India? not found in the embeddings. Skipping.
# Word of not found in the embeddings. Skipping.
# Word market? not found in the embeddings. Skipping.
# Word 2020? not found in the embeddings. Skipping.
# Word of not found in the embeddings. Skipping.
# Word India? not found in the embeddings. Skipping.
# Word of not found in the embeddings. Skipping.
# Word a not found in the embeddings. Skipping.
# Word scenario? not found in the embeddings. Skipping.
# Word India? not found in the embeddings. Skipping.
# Word India? not found in the embeddings. Skipping.
# Word of not found in the embeddings. Skipping.
# Word insurance? not found in the embeddings. Skipping.
# Word of not found in the embeddings. Skipping.
# Word India? not found in the embeddings. Skipping.
# Word of not found in the embeddings. Skipping.
# Word Qantas? not found in the embeddings. Skipping.
# Word ? not found in the embeddings. Skipping.
# Word Boeing? not found in the embeddings. Skipping.
# Word Kdo not found in the embeddings. Skipping.
# Word nejv?tší not found in the embeddings. Skipping.
# Word konkurent not found in the embeddings. Skipping.
# Word ?eské not found in the embeddings. Skipping.
# Word Pojiš?ovny? not found in the embeddings. Skipping.
# Word airports? not found in the embeddings. Skipping.
# Word date? not found in the embeddings. Skipping.
# Word of not found in the embeddings. Skipping.
# Word America? not found in the embeddings. Skipping.
# Word of not found in the embeddings. Skipping.
# Word Airbus? not found in the embeddings. Skipping.
# Word Brazil? not found in the embeddings. Skipping.
# Word companies? not found in the embeddings. Skipping.
# Word airports? not found in the embeddings. Skipping.
# Word of not found in the embeddings. Skipping.
# Word years? not found in the embeddings. Skipping.
# Word of not found in the embeddings. Skipping.
# Word rig? not found in the embeddings. Skipping.
# Word China? not found in the embeddings. Skipping.
# Word Lloyd's not found in the embeddings. Skipping.
# Word of not found in the embeddings. Skipping.
# Word year? not found in the embeddings. Skipping.
# Word Lloyd's? not found in the embeddings. Skipping.
# Word Lloyd's not found in the embeddings. Skipping.
# Word of not found in the embeddings. Skipping.
# Word assets? not found in the embeddings. Skipping.
# Word AXA? not found in the embeddings. Skipping.
# Word cases? not found in the embeddings. Skipping.
# Word Brazil? not found in the embeddings. Skipping.
# Word of not found in the embeddings. Skipping.
# Word Europe? not found in the embeddings. Skipping.
# Word to not found in the embeddings. Skipping.
# Word 2020? not found in the embeddings. Skipping.
# Word 2020? not found in the embeddings. Skipping.
# Word 2020? not found in the embeddings. Skipping.
# Word 2020? not found in the embeddings. Skipping.

# %% [markdown]
# ## Looks like we really need some cleanup here
# Going forward the following approach
# - Remove special characters
# - Remove stop words
# - convert all words to lowercase
#
#
# For stop words, using spaCy's list of english stop words. We will use some regular expressions for cleaning up strings.

# %%
from spacy.lang.en.stop_words import STOP_WORDS
import re

# %% [markdown]
# ### We need to redefine get_phrase_vector function to remove stop words and special characters

# %%
def get_phrase_vector(phrase):
    combined_vectors = None
    normalized_vector = None

    phrase = phrase.lower().strip()
    phrase = re.sub(r'[^a-z0-9\s]', '', phrase) # Removing anything that's not a lower case letter or a digit
    phrase = re.sub(r'\s{2,}', ' ', phrase) # Replacing consecutive spaces with single space

    tokens = [token for token in phrase.split() if token not in STOP_WORDS]

    # Splitting phrase into words
    for word in tokens:
        try:
            vector = wv.get_vector(word)
            if combined_vectors is None:
                combined_vectors = vector
            else:
                combined_vectors = combined_vectors + vector
        except KeyError as e:
            print(f"Word {word} not found in the embeddings. Skipping.")

    # Normalising the vector, not sure if this is correct for word2vec vectors
    if combined_vectors is not None:
        norm = np.linalg.norm(combined_vectors)
        normalized_vector = combined_vectors / norm
    
    return normalized_vector

# %%
# Let's try again
phrases['Embedding'] = phrases['Phrases'].apply(get_phrase_vector)
# Out:
# Word axa not found in the embeddings. Skipping.
# Word 2020 not found in the embeddings. Skipping.
# Word 2020 not found in the embeddings. Skipping.
# Word cholamandalam not found in the embeddings. Skipping.
# Word 2020 not found in the embeddings. Skipping.
# Word qantas not found in the embeddings. Skipping.
# Word kdo not found in the embeddings. Skipping.
# Word nejvt not found in the embeddings. Skipping.
# Word konkurent not found in the embeddings. Skipping.
# Word esk not found in the embeddings. Skipping.
# Word pojiovny not found in the embeddings. Skipping.
# Word aban not found in the embeddings. Skipping.
# Word abraham not found in the embeddings. Skipping.
# Word lloyds not found in the embeddings. Skipping.
# Word lloyds not found in the embeddings. Skipping.
# Word lloyds not found in the embeddings. Skipping.
# Word axa not found in the embeddings. Skipping.
# Word 2020 not found in the embeddings. Skipping.
# Word 2020 not found in the embeddings. Skipping.
# Word 2020 not found in the embeddings. Skipping.
# Word 2020 not found in the embeddings. Skipping.

# %% [markdown]
# Data is much cleaner now, only some words have been skipped.

# %%
phrases
# Out:
#                                               Phrases  \
# 0                  how company compares to its peers?
# 1   what is the detailed income statement breakdow...
# 2                   world premium penetration in 2020
# 3   How does the forecasted insurance premium pene...
# 4   what are the total losses for companies in cou...
# 5                Insurance premiums market in Country
# 6   How have the profit margins been for the airli...
# 7   What is the complete profile of the top oil rigs?
# 8                what is company general information?
# 9    How is the airline industry performing globally?
# 10  how does economic profit for in country compar...
# 11            most profitable insurance company India
# 12  Give me a detailed breakup of the income and e...
# 13              Show me all the oil rigs in the world
# 14  What were the premiums earned by the Indian in...
# 15  How much have premiums grown as compared to cl...
# 16  Which are the best performing insurance firms ...
# 17              What is the ROE of the Indian market?
# 18  What profits were clocked by Cholamandalam in ...
# 19  What is the premiums market share of the top 5...
# 20  How will the Brazilian insurance market perfor...
# 21  Which are the main distribution channels in In...
# 22  What are the risks in the motor insurance segm...
# 23  What is the demand potential of India for insu...
# 24  How do premiums break down by lines of busines...
# 25                 What is the share price of Qantas?
# 26               How many passengers are carried in ?
# 27    Which are the aircrafts manufactured by Boeing?
# 28        Kdo je nejv?tší konkurent ?eské Pojiš?ovny?
# 29                        Which are the top airports?
# 30            How many fatal air accidents till date?
# 31  What is the flow of air traffic in North America?
# 32                       What is the fleet of Airbus?
# 33                     Airlines profitability Brazil?
# 34                   Mergers among airline companies?
# 35            Which are the most profitable airports?
# 36  What has the capacity movement of airline comp...
# 37               Details of the Aban Abraham oil rig?
# 38         How big is the airlines industry in China?
# 39  How much money did Lloyd's of London make last...
# 40  What was the Calendar year COR versus the Acci...
# 41  Which Lloyd's syndicates owns the maximum numb...
# 42           List key performance indicators for AXA?
# 43           What are the most prominent legal cases?
# 44           How does oil industry perform in Brazil?
# 45  What is the main driver of growth in automobil...
# 46  Which country in Europe is going to grow the m...
# 47         What are the biggest acquisitions in 2020?
# 48      How impacted is the airline industry in 2020?
# 49  What are the most prominent bankruptcies in 2020?
#
#                                             Embedding
# 0   [-0.02834456, -0.020169953, -0.0019547972, 0.0...
# 1   [-0.028401444, -0.05971302, -0.10196523, -0.07...
# 2   [0.051207986, 0.04113356, 0.0059830635, 0.0205...
# 3   [-0.013715633, 0.03623202, -0.031086965, 0.081...
# 4   [-0.035838407, 0.017012784, 0.030302277, 0.024...
# 5   [-0.0076315925, 0.0039857305, 0.0035840678, 0....
# 6   [-0.03775526, 0.019381352, -0.034458663, 0.077...
# 7   [-0.04677956, 0.015654752, -0.11058587, 0.0353...
# 8   [-0.023916712, -0.07000852, 0.027442915, -0.10...
# 9   [-0.015515315, -0.06615166, -0.042649485, 0.03...
# 10  [-0.027235992, 0.017009964, -0.009700883, 0.06...
# 11  [-0.05121067, -0.034810774, -0.023117613, 0.07...
# 12  [-0.04675864, -0.035490047, -0.1256722, 0.0435...
# 13  [-0.04349492, -0.016176114, -0.012890941, 0.04...
# 14  [-0.008816143, -0.016275955, -0.027831884, 0.0...
# 15  [-0.026891684, 0.05291493, -0.03245419, 0.0797...
# 16  [-0.063241765, 0.030301308, 0.028924717, 0.105...
# 17  [-0.09656534, -0.024257028, -0.033242542, 0.04...
# 18  [0.013728725, 0.051845122, 0.045296267, 0.0219...
# 19  [-0.024664564, -0.04159281, -0.021625295, 0.07...
# 20  [0.026512071, 0.031051429, -0.041092474, 0.048...
# 21  [-0.038664564, 0.008881208, 0.0153547, 0.07076...
# 22  [-0.04051092, 0.048810437, -0.021815248, 0.077...
# 23  [-0.04018463, 0.03943221, 0.013794307, 0.09420...
# 24  [-0.008941138, 0.021160154, -0.025014093, 0.07...
# 25  [0.020905932, -0.018215625, -0.06557625, 0.078...
# 26  [0.0898998, 0.04237213, 0.013318489, 0.0494744...
# 27  [-0.017137125, 0.07749292, 0.0589951, 0.034735...
# 28  [0.03499868, 0.10055959, 0.047075693, 0.016266...
# 29  [0.040059015, 0.0089642545, 0.060788855, 0.099...
# 30  [0.0030515182, 0.020153515, 0.06475666, 0.0237...
# 31  [0.03208438, 0.0026339036, 0.027756717, 0.0069...
# 32  [0.04794069, 0.053184204, 0.05071338, -0.01385...
# 33  [-0.024219662, 0.032653295, -0.010544433, 0.09...
# 34  [-0.008380722, -0.023279784, -0.03851909, 0.05...
# 35  [-0.0012171207, -0.011664073, 0.016431129, 0.1...
# 36  [0.026426548, 0.005300674, 0.02101491, 0.07712...
# 37  [-0.010002959, -0.03943363, -0.07015563, -0.06...
# 38  [-0.008177064, -0.020477606, -0.026918491, 0.1...
# 39  [-0.04773174, 0.06676157, -0.039120562, 0.1518...
# 40  [-0.03136862, 0.101098865, -0.0075643077, 0.01...
# 41  [0.05036898, -0.054632187, 0.043958385, -0.091...
# 42  [-0.023132643, 0.0028356141, 0.033803508, 0.01...
# 43  [-0.02963097, 0.09077643, -0.04125366, 0.04320...
# 44  [-0.082354724, -0.024241364, -0.062031526, -0....
# 45  [-0.01921244, -0.06804061, 0.0026844968, 0.038...
# 46  [-0.023517763, 0.07793141, 0.019751847, 0.1340...
# 47  [-0.04416021, 0.06789798, -0.017186677, 0.0375...
# 48  [-0.039121833, -0.06099118, -0.03941545, 0.037...
# 49  [-0.008362028, 0.03678297, -0.07904107, 0.0548...

# %% [markdown]
# ### This solves 1(a)

# %% [markdown]
# ## Calculating distances for all combinations of phrases
# Using scipy for calculating distances for all combination of points

# %%
from scipy.spatial.distance import cdist

# %%
vectors = np.array([x for x in phrases['Embedding']])
distances = cdist(vectors, vectors, 'euclidean')

# %%
distances
# Out:
# array([[0.        , 1.18295502, 1.17092799, ..., 1.21189768, 1.09011142,
#         1.31037283],
#        [1.18295502, 0.        , 1.25682913, ..., 1.31476865, 1.23629643,
#         1.2583098 ],
#        [1.17092799, 1.25682913, 0.        , ..., 1.21310148, 1.20973627,
#         1.29871919],
#        ...,
#        [1.21189768, 1.31476865, 1.21310148, ..., 0.        , 1.26371416,
#         1.17303795],
#        [1.09011142, 1.23629643, 1.20973627, ..., 1.26371416, 0.        ,
#         1.15673771],
#        [1.31037283, 1.2583098 , 1.29871919, ..., 1.17303795, 1.15673771,
#         0.        ]])

# %%
# Confirming the shape of the distance array, it should be 50x50 for all combinations of embeddings
distances.shape
# Out:
# (50, 50)

# %% [markdown]
# ### All pairwise distances for this dataset. This solves 1b.

# %% [markdown]
# ## Now to find matching phrases to a given phrase

# %%
user_input = input()
# Out:
#  what is the profitability of airline companies in Indian market?

# %%
print(user_input)
# Out:
# what is the profitability of airline companies in Indian market?

# %%
def get_closest_phrase(input_phrase):
    phrase_vector = get_phrase_vector(input_phrase)
    vectors = np.array([x for x in phrases['Embedding']])
    distances = cdist([phrase_vector], vectors)
    index_min = np.argmin(distances[0])
    return phrases["Phrases"][index_min], distances[0][index_min]

# %%
get_closest_phrase(user_input)
# Out:
# ('Airlines profitability Brazil?', 0.6282487228434344)

# %% [markdown]
# ### Closest phrase in the dataset from user input. This solves 1c.
